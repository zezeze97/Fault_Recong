# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py 
import cv2
import os
import segyio
plt.rcParams["figure.figsize"] = (10, 5)

# %% [markdown]
# # Visualize Thebe

# %%
seis = np.load('./Fault_data/public_data/precessed/test/seis/seistest.npy', mmap_mode='r')
gt = np.load('./Fault_data/public_data/precessed/test/fault/faulttest.npy', mmap_mode='r')
pred = np.load('./MIM-Med3D/output/Fault_Finetuning/swin_unetr_base_simmim500e_p16_public_256_flip_rotate_aug_4x4_rerun/thebe_pred/seistest_score.npy', mmap_mode='r')

# %%
th = 0.52
idx = 200
plt.subplot(2,1,1)
fig = plt.imshow(seis[idx, :, :].T, cmap='seismic')
fig = plt.imshow(gt[idx, :, :].T, cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(2,1,2)
fig = plt.imshow(seis[idx, :, :].T, cmap='seismic')
# fig = plt.imshow((pred[idx, :, :] > th).astype(np.uint8).T, cmap='gray', alpha=0.5)
fig = plt.imshow(pred[idx, :, :].T, cmap='cool')
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# # Visualize Real Label Data(501 x 501 x 801)

# %%
seis = segyio.tools.cube('./Fault_data/real_labeled_data/origin_data/seis/mig_fill.sgy')
gt = segyio.tools.cube('./Fault_data/real_labeled_data/origin_data/fault/label_fill.sgy')
pred = np.load('./mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_mix_data_force_3_chan-512x512_per_image_normal_pos_weight_10/real_label_data_pred/score.npy', mmap_mode='r')

# %%
th = 0.5
idx = 10
plt.subplot(1,2,1)
fig = plt.imshow(seis[idx, :, :].T, cmap='seismic')
fig = plt.imshow(gt[idx, :, :].T, cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,2,2)
fig = plt.imshow(seis[idx, :, :].T, cmap='seismic')
fig = plt.imshow((pred[idx, :, :] > th).astype(np.uint8).T, cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# # Visualize New Project Data
#
# ## 清苑北

# %%
seis = segyio.tools.cube('./Fault_data/project_data_v1/labeled/qyb/seis/20230412_QY-PSTM-STK-CG-TO-DIYAN.sgy')
gt = segyio.tools.cube('./Fault_data/project_data_v1/labeled/qyb/faults/expression_result.sgy')
pred = np.load('./mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_mix_data_force_3_chan-512x512_per_image_normal_pos_weight_10/project_data_v1_pred/qyb/score.npy', mmap_mode='r')

# %%
th = 0.5
idx = 1
plt.subplot(2,1,1)
fig = plt.imshow(seis[idx, :, :], cmap='seismic')
fig = plt.imshow(gt[idx, :, :], cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(2,1,2)
fig = plt.imshow(seis[idx, :, :], cmap='seismic')
fig = plt.imshow((pred[idx, :, :] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# ## 高家堡

# %%
seis = segyio.tools.cube('./Fault_data/project_data_v1/labeled/Ordos/gjb/seis/L500_1500_T500_2000_aa_pstm_0922_cg.sgy')
gt = segyio.tools.cube('./Fault_data/project_data_v1/labeled/Ordos/gjb/faults/expression_result.sgy')
pred = np.load('./mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_mix_data_force_3_chan-512x512_per_image_normal_pos_weight_10/project_data_v1_pred/Ordos/gjb/score.npy', mmap_mode='r')

# %%
th = 0.5
idx = 504
plt.subplot(1,2,1)
fig = plt.imshow(seis[idx, :, 150:501], cmap='seismic')
fig = plt.imshow(gt[idx, :, :], cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,2,2)
fig = plt.imshow(seis[idx, :, 150:501], cmap='seismic')
fig = plt.imshow((pred[idx, :, 150:501] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# ## 平凉

# %%
seis = segyio.tools.cube('./Fault_data/project_data_v1/labeled/Ordos/pl/seis/20230419_PLB-YW-pstm-post-yanshou-Q_biaoqian.sgy')
gt = segyio.tools.cube('./Fault_data/project_data_v1/labeled/Ordos/pl/faults/pstm_pre22.sgy')
pred = np.load('./mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_mix_data_force_3_chan-512x512_per_image_normal_pos_weight_10/project_data_v1_pred/Ordos/pl/score.npy', mmap_mode='r')

# %%
th = 0.5
idx = 17
plt.subplot(2,1,1)
fig = plt.imshow(seis[idx, :, :], cmap='seismic')
fig = plt.imshow(gt[idx, :, :], cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(2,1,2)
fig = plt.imshow(seis[idx, :, :], cmap='seismic')
fig = plt.imshow((pred[idx, :, :] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# ## 平武

# %%
seis = segyio.tools.cube('./Fault_data/project_data_v1/labeled/Ordos/yw/seis/mig.sgy')
gt = segyio.tools.cube('./Fault_data/project_data_v1/labeled/Ordos/yw/faults/fault_volume_converted.sgy')
pred = np.load('./mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_mix_data_force_3_chan-512x512_per_image_normal_pos_weight_10/project_data_v1_pred/Ordos/yw/score.npy', mmap_mode='r')

# %%
th = 0.5
idx = 8
plt.subplot(2,1,1)
fig = plt.imshow(seis[idx, :, :], cmap='seismic')
fig = plt.imshow(gt[idx, :, :], cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(2,1,2)
fig = plt.imshow(seis[idx, :, :], cmap='seismic')
fig = plt.imshow((pred[idx, :, :] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %%
predict_path = '/home/zhangzr/Fault_Recong/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_2Dfault_0519_slice_split_force3chan-256x256_per_image_norm_pos_weight_10_dilate/predict'
gt_path = '/home/zhangzr/Fault_Recong/Fault_data/2Dfault_0519_256/converted_slice_split/val'
name = '1956_70'
seis = np.load(os.path.join(gt_path, 'image', f'{name}.npy'))
label = cv2.imread(os.path.join(gt_path, 'ann', f'{name}.png'), cv2.IMREAD_UNCHANGED)
pred = np.load(os.path.join(predict_path, f'{name}.npy'))

# %%
th = 0.5
plt.subplot(1,2,1)
fig = plt.imshow(seis, cmap='seismic')
fig = plt.imshow(label, cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,2,2)
fig = plt.imshow(seis, cmap='seismic')
fig = plt.imshow((pred > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %%
pred = np.load('/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Finetuning/swin_unetr_base_simmim_p16_real_labeled_crop_192-pos-weight-10-dilate-1/test_pred/mig_fill_score.npy')
seis = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/origin_data/seis/mig_fill.sgy')[373:,:,:]
label = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/origin_data/fault/label_fill.sgy')[373:,:,:]

# %%
th = 0.5
slice_id = 1
plt.subplot(1,2,1)
fig = plt.imshow(seis[slice_id,:,:].T, cmap='seismic')
fig = plt.imshow(label[slice_id,:,:].T, cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,2,2)
fig = plt.imshow(seis[slice_id,:,:].T, cmap='seismic')
fig = plt.imshow((pred[slice_id,:,:] > th).astype(np.uint8).T, cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# # Visualize Public Data Predict

# %%
# unetr_base_supbaseline_p16_public_filted_no_fault_pred = np.load('/home/zhangzr/Fault_Recong/MIM-Med3D/output/Fault_Baseline/unetr_base_supbaseline_p16_public_filted_no_fault/test_pred/seistest_score.npy', mmap_mode='r')
# unetr_base_supbaseline_p16_public_filted_003_pred = np.load('/home/zhangzr/Fault_Recong/MIM-Med3D/output/Fault_Baseline/unetr_base_supbaseline_p16_public_filted_003/test_pred/seistest_score.npy', mmap_mode='r')
# swin_unetr_base_pred = np.load('/home/zhangzr/Fault_Recong/MIM-Med3D/output/Fault_Baseline/swin_unetr_base_supbaseline_p16_public_filted_no_fault/test_pred/seistest_score.npy', mmap_mode='r')
# swin_2d_512_25d_catmax97_pred = np.load('/home/zhangzr/Fault_Recong/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_public_slice_25d-512x512-catmax97/predict/score.npy', mmap_mode='r')
# swin_2d_512_25d_pred = np.load('/home/zhangzr/Fault_Recong/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_public_slice_25d-512x512/predict/score.npy', mmap_mode='r')
# swin_2d_256_25d_pred = np.load('/home/zhangzr/Fault_Recong/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_public_slice_25d-256x256/predict/score.npy', mmap_mode='r')
# swin_2d_128_25d_pred = np.load('/home/zhangzr/Fault_Recong/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_public_slice_25d-128x128/predict/score.npy', mmap_mode='r')
# swin_2d_512_25d_dilate_pred = np.load('/home/zhangzr/Fault_Recong/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_public_slice_25d-512x512-dilate/predict/score.npy', mmap_mode='r')
zoom_pred = np.load('/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline/swin_unetr_base_supbaseline_p16_public_192x384x384_zoom/test_pred/seistest_score.npy', mmap_mode='r')
pred = np.load('/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline_new_normalization/swin_unetr_base_supbaseline_p16_public_192_bce_pos_weight_10/test_pred/seistest_score.npy', mmap_mode='r')
gt = np.load('/home/zhangzr/FaultRecongnition/Fault_data/public_data/precessed/test/fault/faulttest.npy', mmap_mode='r')
seis = np.load('/home/zhangzr/FaultRecongnition/Fault_data/public_data/precessed/test/seis/seistest.npy', mmap_mode='r')

# %%
th = 0.5
slice_id = 15
plt.subplot(3,1,1)
fig = plt.imshow(seis[slice_id,:,800:1300].T, cmap='seismic')
fig = plt.imshow(gt[slice_id,:,800:1300].T, cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(3,1,2)
fig = plt.imshow(seis[slice_id,:,800:1300].T, cmap='seismic')
fig = plt.imshow((zoom_pred[slice_id,:,800:1300] > th).astype(np.uint8).T, cmap='gray', alpha=0.5)
fig.axes.set_title('zoom (1, 0.5, 0.5) pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(3,1,3)
fig = plt.imshow(seis[slice_id,:,800:1300].T, cmap='seismic')
fig = plt.imshow((pred[slice_id,:,800:1300] > th).astype(np.uint8).T, cmap='gray', alpha=0.5)
fig.axes.set_title('pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

"""
plt.subplot(1,6,1)
fig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')
fig = plt.imshow(gt[slice_id,:,800:1300], cmap='gray', alpha=0.5)
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,6,2)
fig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')
fig = plt.imshow((swin_2d_512_25d_catmax97_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('swin_2d_512_25d_catmax97_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,6,3)
fig = plt.imshow(seis[slice_id,:,:], cmap='seismic')
fig = plt.imshow((swin_2d_512_25d_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('swin_2d_512_25d_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,6,4)
fig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')
fig = plt.imshow((swin_2d_256_25d_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('swin_2d_256_25d_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,6,5)
fig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')
fig = plt.imshow((swin_2d_128_25d_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('swin_2d_128_25d_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(1,6,6)
fig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')
fig = plt.imshow((swin_2d_512_25d_dilate_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)
fig.axes.set_title('swin_2d_512_25d_dilate_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()
"""
# Out:
# "\nplt.subplot(1,6,1)\nfig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')\nfig = plt.imshow(gt[slice_id,:,800:1300], cmap='gray', alpha=0.5)\nfig.axes.set_title('gt')\nfig.axes.xaxis.set_visible(False)\nfig.axes.yaxis.set_visible(False)\nplt.subplot(1,6,2)\nfig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')\nfig = plt.imshow((swin_2d_512_25d_catmax97_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)\nfig.axes.set_title('swin_2d_512_25d_catmax97_pred')\nfig.axes.xaxis.set_visible(False)\nfig.axes.yaxis.set_visible(False)\nplt.subplot(1,6,3)\nfig = plt.imshow(seis[slice_id,:,:], cmap='seismic')\nfig = plt.imshow((swin_2d_512_25d_pred[slice_id,:,800:1300] > th).astype(np.uint8), cmap='gray', alpha=0.5)\nfig.axes.set_title('swin_2d_512_25d_pred')\nfig.axes.xaxis.set_visible(False)\nfig.axes.yaxis.set_visible(False)\nplt.subplot(1,6,4)\nfig = plt.imshow(seis[slice_id,:,800:1300], cmap='seismic')\nfig = plt.imshow((swin_2d_256_25d_pred[slice_id,:,8
# ...

# %%
pred_val_path = '/home/zhangzr/Fault_Recong/MIM-Med3D/output/Fault_Baseline/unetr_base_supbaseline_p16_public_filted_003/train_pred_crop'
gt_val_path = '/home/zhangzr/Fault_Recong/Fault_data/public_data/crop_filted_003/train'
idx = 60
with h5py.File(os.path.join(pred_val_path, f'{idx}.h5')) as f:
    pred = f['predictions'][:]
with h5py.File(os.path.join(gt_val_path, f'{idx}.h5')) as f:
    label = f['label'][:]
    seis = f['raw'][:]

# %%
slice = 90
# th = 0.5
plt.subplot(1,2,1)
plt.imshow(seis[slice,:,:], cmap='seismic')
plt.imshow(label[slice,:,:], cmap='gray', alpha=0.5)
plt.title('GT')
plt.subplot(1,2,2)
plt.imshow(seis[slice,:,:], cmap='seismic')
plt.imshow(pred[slice,:,:] , cmap='gray', alpha=0.5)
plt.title('Pred')
# Out:
# Text(0.5, 1.0, 'Pred')

# %% [markdown]
# # Read Seis

# %%
seis = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/origin_data/seis/mig_fill.sgy')
label = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/origin_data/fault/label_fill.sgy')
with h5py.File('/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline/unetr_base_supbaseline_p16_v01/preds_whole/mig_fill.h5', 'r') as f:
    unetr_baseline_pred = f['predictions'][:]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/zhangzr/Fault_Recong/visualize.ipynb 单元格 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B162.105.94.12/home/zhangzr/Fault_Recong/visualize.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> seis = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/origin_data/seis/mig_fill.sgy')
#       <a href='vscode-notebook-cell://ssh-remote%2B162.105.94.12/home/zhangzr/Fault_Recong/visualize.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> label = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/origin_data/fault/label_fill.sgy')
# ...

# %%
slice_id = 600
plt.subplot(1,2,1)
plt.imshow(seis[:,:,slice_id], cmap='seismic')
plt.imshow(label[:,:,slice_id], cmap='gray', alpha=0.7)
plt.subplot(1,2,2)
plt.imshow(seis[:,:,slice_id], cmap='seismic')
plt.imshow(unetr_baseline_pred[:,:,slice_id], cmap='gray', alpha=0.7)

# %% [markdown]
# # Visualize Predictions

# %%
seis = segyio.tools.cube('/home/zhangzr/FaultRecongnition/Fault_data/real_data/seis.sgy')
with h5py.File('/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline/unetr_base_supbaseline_p16_v01/real_preds/seis.h5', 'r') as f:
    unetr_baseline_pred = f['predictions'][:]
with h5py.File('/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline/swin_unetr_base_supbaseline_p16_v01/real_preds/seis.h5', 'r') as f:
    swin_unetr_baseline_pred = f['predictions'][:]

swin_transformer_pred = np.load('/home/zhangzr/FaultRecongnition/mmsegmentation/output/swin-base-patch4-window7_upernet_8xb2-160k_fault_public_slice-256x256/real_data_predict/predict.npy', mmap_mode='r')

# %%
slice_id = 30
plt.subplot(4,1,1)
fig = plt.imshow(seis[slice_id,:,:], cmap='seismic')
fig.axes.set_title('seis')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(4,1,2)
fig = plt.imshow(1-unetr_baseline_pred[slice_id,:,:], cmap='binary')
fig.axes.set_title('unetr_baseline_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(4,1,3)
fig = plt.imshow(1-swin_unetr_baseline_pred[slice_id,:,:], cmap='binary')
fig.axes.set_title('swin_unetr_baseline_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(4,1,4)
fig = plt.imshow(1-swin_transformer_pred[slice_id,:,:], cmap='binary')
fig.axes.set_title('swin_transformer_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %%
def crop_center(img,cropx,cropy):
    y,x = img.shape
    startx = x//2 - cropx//2
    starty = y//2 - cropy//2    
    return img[starty:starty+cropy, startx:startx+cropx]

# %%
slice_id = 500
plt.subplot(3,1,1)
fig = plt.imshow(crop_center(seis[:,slice_id,:], 101, 101))
fig.axes.set_title('seis')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(3,1,2)
fig = plt.imshow(1-crop_center(unetr_baseline_pred[:,slice_id,:], 101, 101), cmap='binary')
fig.axes.set_title('unetr_baseline_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(3,1,3)
fig = plt.imshow(1-crop_center(swin_unetr_baseline_pred[:,slice_id,:], 101, 101), cmap='binary')
fig.axes.set_title('swin_unetr_baseline_pred')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# # Validation data

# %%
ids = 99
with h5py.File(f'/home/zhangzr/FaultRecongnition/Fault_data/real_labeled_data/crop/val/{ids}.h5', 'r') as f:
    seis = f['raw'][:]
    gt = f['label'][:]

with h5py.File(f'/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline/unetr_base_supbaseline_p16_v01/preds/{ids}.h5', 'r') as f:
    unetr_baseline_pred = f['predictions'][:]

with h5py.File(f'/home/zhangzr/FaultRecongnition/MIM-Med3D/output/Fault_Baseline/swin_unetr_base_supbaseline_p16_v01/preds/{ids}.h5', 'r') as f:
    swin_unetr_baseline_pred = f['predictions'][:]

# %%
slice_id = 100
plt.subplot(4,1,1)
fig = plt.imshow(seis[:,:,slice_id])
fig.axes.set_title('seis')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(4,1,2)
fig = plt.imshow(1-unetr_baseline_pred[:,:,slice_id], cmap='binary')
fig.axes.set_title('unetr_baseline')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(4,1,3)
fig = plt.imshow(1-swin_unetr_baseline_pred[:,:,slice_id], cmap='binary')
fig.axes.set_title('swin_unetr_baseline')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.subplot(4,1,4)
fig = plt.imshow(1-gt[:,:,slice_id], cmap='binary')
fig.axes.set_title('gt')
fig.axes.xaxis.set_visible(False)
fig.axes.yaxis.set_visible(False)
plt.show()
